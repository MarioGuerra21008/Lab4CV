# %% [markdown]
# # Laboratorio 4 - Visión por Computadora
# ## Integrantes:
#
# - Javier Alvarado - 21188
# - Mario Guerra - 21008
# - Emilio Solano - 21212

# %% [markdown]
# ![Imagen de ejemplo](data:image/png;base64,...)

# %%
# Code here

# %% [markdown]
# ![Imagen de ejemplo](data:image/png;base64,...)

# %%
# Code here

# %% [markdown]
# ![Imagen de ejemplo](data:image/png;base64,...)

# %%
# Code here

# %% [markdown]
# ![Imagen de ejemplo](data:image/png;base64,...)

# %%
# Code here

# %% [markdown]
# ![Imagen de ejemplo](data:image/png;base64,...)

# %%
# Code here

# %% [markdown]
# ![Imagen de ejemplo](data:image/png;base64,...)

# %%
# Code here
